# %% [markdown]
# ---
# comments: true
# layout: post
# title: Peer Grading
# type: hacks
# courses: { csp: {week: 7} }
# categories: [C4.1]
# ---

# %% [markdown]
# Data Abstraction Grading
#
# Aidan Lau 4/4
#
#  Integer operation 1/1
# Float operation 1/1
# Format manipulation 1/1
# Greeting with input and output 1/1
# Austin Zhang- 4/4
# num1int = 7
# num2int = 8
# sum = num2int + num1int
# print(sum)
# 1/1
# float1 = 5.6
# float2 = 8.2
# quotient = 5.6/8.2
# print(quotient)
# 1/1
# message = "My first name is {0} and my last name is {1}"
# print(message.format("Austin", "Zhang"))
# print(message.format("David", "Lee"))
# 1/1
# name = input("Enter your name: ")
# print("Hi! How are you,", name)  1/1
#
#
#
#
# Hayden Chen
#
#
#  Integer operation 1/1
# Float operation 1/1
# Format manipulation 1/1
# Greeting with input and output 1/1
#
# Anusha Khobare
# Did not complete number one. 0/1
#
#
# var1 = 7
# var2 = 9
# var3 = 2
# var4 = 9
# variable_list = [var1, var2, var3, var4]
# print(variable_list)
#
# Made a variable list instead of printing out the sum of two variables. 0/1
#
#
# age = 15
# name = "Anusha"
# year = "sophmore"
# print("Hello, I am " + name + " and, I am " + str(age) + " years old." + " I am a " + year)
#
# Made a message with variables instead of dividing two float variables. 0/1.
# message = "Hi. My name is {} and I am {} years old"
# formatted_message = message.format(name, age)
# print(formatted_message)
#
# Answer only includes one set of variables, not two. 0/1.
#
# Overall: 0/4
#
#
# Sri Surapeneni- 4/4
# ##Greeting
# name_input = input("Enter your name: ")
# greeting = f"Hi, {name_input}! Welcome to CSP."
# print(greeting)
#
# ##Question 1
# num1Int = 2
# num2Int = 4
# print(num1Int + num2Int)
#
# ##Question 2
# float1 = 4.6
# float2 = 2.3
# print(float1 / float2)
#
# #Question 3
# sentence = "{0} is {1} cool"
#
# print(sentence.format("Sri", "very"))
#
# print (sentence.format("Srini", "not"))
#
# Jon Liu-3/4
# num1Int = 3
# num2Int = 4
# print(num1Int + num2Int) 1/1
#
# float1 = 2.0
# float2 = 7.0
# print(float2/float1)  1/1
#
# phold1 = "eat"
# phold2 = "sunday"
# print(f"i like to {phold1} bananas every {phold2}")   1/1
#
# Did not do greeting with input and output so 0/1
#
# Anvay Yadav 4/4
# 		# Question 1: Integer Operation 1/1
# num1Int = 10
# num2Int = 5
# sum_of_integers = num1Int + num2Int
# print(f"Sum of {num1Int} and {num2Int} is {sum_of_integers}\n")
#
# # Question 2: Float Operation 1/1
# float1 = 10.0
# float2 = 2.5
# quotient_of_floats = float1 / float2
# print(f"Quotient of {float1} and {float2} is {quotient_of_floats}\n")
#
# # Question 3: Format Manipulation 1/1
# message = "Hello, {}! Today's weather is {}."
# name = input("What is your name?")
# weather = input("What is the weather today?")
# formatted_message = message.format(name, weather)
# print(formatted_message)
#
# # Question 4: Goodbye 1/1
# user_name = input("Enter your name: ")
# greeting = f"Hello, {user_name}! Have a good rest of your day!"
# print(greeting)
#
#
# Abby Albert-3/4
#
# num1Int = 10
# num2Int = 15
# print(num1Int+num2Int)  1/1 integer operation
#
# float1 = 10
# float2 = 2
# print(float1/float2)  1/1 float operation
#
# var1 = "hello,"
# var2 = "how are you"
# print(var1, var2)  greeting 1/1
#
# 0/1 format manipulation
#
#
#
# Deva Sasikumar
# 0/4
# Does not have any of the required code
# Nupur Bhala
# 2/4
# #1 is not there 0/1
# #2 is not there
# #3 is correct, and can also be #4 2/2
# Tanvi Movva
# 2/4 (same as nupur)
# #1 is not there 0/1
# #2 is not there
# #3 is correct, and can also be #4 2/2
#
#
# Sreeja Raj
# ¾
# Incorrect code for #1 0/1
#
# Correct for the rest 3/3
# Shuban Pal
# 2/4
# Only completed sum of integers and quotient of two numbers did not do greeting or format manipulation
# Tarun Jaikumar - 3/4
# ¾
# Forgot greeting with input and output
# #Question 1
# def sumofint(num1Int,num2Int):
#     return num1Int+num2Int
# num1int=3
# num2int=2
# print("The sum of the float "+str(num1int)+" and"+ str(num2int)+" is "+str(sumofint(num1int,num2int)))
#
# #Question 2
# def sumoffloat(num1float,num2float):
#     return num1float+num2float
# num1float=3.1
# num2float=2.5
# print("The sum of the float "+str(num1float)+" and "+str(num2float)+" is "+str(sumoffloat(num1float,num2float)))
#
# #Question 3
# # string1="Dogs"
# string1=input("What is one thing you like?")
# # string2="Cats"
# string2=input("What is another thing you like?")
# message="I like "+string1+" and "+string2+"."
# print(message)
#
#
#
# Aiden Kim - 4/4
# Greeting 1/1
# #Greeting With Variables
# greeting = "Hello"
# name = "Chris"
# print(greeting + " " + name )
# Integer operation 1/1
# #Integer Operation
# int1 = 5
# int2 = 10
# print(int1 + int2)
# Float operation 1/1
# #Float Operation/
# float1 = 1123551.23
# float2 = 57345.50
# print(float1 + float2)
# Format manipulation 1/1
# #Format Manipulation
# message = "{0} has {1} siblings"
# print(message.format("Peyton", "2"))
# Tarun
# Did not complete question 1.
# Printed the sum of two integers. 1/1.
# def sumofint(num1Int,num2Int):
# return num1Int+num2Int
# num1int=3
# num2int=2
# print("The sum of the float "+str(num1int)+" and"+ str(num2int)+" is "+str(sumofint(num1int,num2int)))
# Used decimal integers for float variables but did not divide them. 0/1.
# def sumoffloat(num1float,num2float):
# return num1float+num2float
# num1float=3.1
# num2float=2.5
# print("The sum of the float "+str(num1float)+" and "+str(num2float)+" is "+str(sumoffloat(num1float,num2float)))
#
# Instead of having two sets of variables he took the user input instead. .5/1.
# string1=input("What is one thing you like?")
# # string2="Cats"
# string2=input("What is another thing you like?")
# message="I like "+string1+" and "+string2+"."
# print(message)
#
# Tejas Manoj
# Submission link doesn’t work
# Payton leigh 4/4
# #Question 1
# var1 = 7
# var2 = 9
# print(var1 + var2)
# #Question 2
# float1 = 7.0
# float2 = 14.0
# print(float1 / float2)
# #Question 3
# age = 16
# name = "Peyton"
# year = "junior"
# print("Hello, I am " + name + " and I am " + str(age) + " years old." + " I am a " + year)
# message = "Hi. My name is {} and I am {} years old"
# formatted_message = message.format(name, age)
# print(formatted_message
#
#
# Nitin Balaji
# No answer for number one. 0/1.
# Code works and the output is correct. 1/1.
# num1 = 5
# num2 = 6
# print(num1+num2)
#
# Code works and the output is correct. 1/1.
# float1 = 5.0
# float2 = 2.5
# print(float1/float2)
#
# Code was supposed to use at least two combinations of variables that would output two versions of the message. This only has one combination (ie. name 1 and name 2). To correct this there would have to be name 3 and name 4. The format does not match what was taught and the code does not run. 0/1.
# message = “Hello {name1} and {name2}! How can I assist you today?”
# name1 = “John” n
# ame2 = “Alice”
# formatted_message = message.format(name1=name1, name2=name2) print(formatted_message)
#
# Overall: 2/4
# Srinavas Nampali - 4/4
# All code was correct
#
#
# num1Int = 10
# num2Int = 20
# sum_result = num1Int + num2Int
# print("The sum of", num1Int, "and", num2Int, "is:", sum_result)
# float1 = 3.5
# float2 = 2.0
# quotient = float1 / float2
# print("The quotient of", float1, "and", float2, "is:", quotient)
# message = "My name is {} and I am a {}."
# name = "Srinivas"
# occupation = "software engineer"
# formatted_message = message.format(name, occupation)
# print(formatted_message)
#
#
# Tanuj Nimagadda
# ¾
# #1 was incorrect, he needed to add two variables and print the sum 0/1
# 3/3 for the rest of the questions
# No answer for number one. 0/1.
# Code lists numbers instead of finding the sum. 0/1.
# var1 = 7
# var2 = 9
# var3 = 2
# var4 = 8
# VAR = [var1, var2, var3, var4]
# print(VAR)
# Code divides two numbers that aren’t decimals. Float variables are for decimal numbers. 0/1.
# float1 = 10
# float2 = 2
# print(float1/float2)
# Code does not have a standard message to which variables are inputted into. Only two variables are used instead of four but can count as a greeting. 1/2.
# var1 = "hello,"
# var2 = "how are you"
# print(var1, var2)
#
#
# Rayyan Darugar
# 2/4
# #1 is incorrect, he needed to add the variables 0/1, instead he made a list
# #2 is correct 1/1
# #3 is not there 0/1
# #4 is correct 1/1
# var1 = 7
# var2 = 9
# var3 = 2
# var4 = 8
# varsList = [var1, var2, var3, var4]
# print(varsList)
# Did not print the sum of two numbers 0/1
#
#
# 1/1
# float1 = 10.0
# float2 = 2.0
# print(float1/float2)
#
#
# 1/1  greeting
# greeting = "hello,"
# question = "how are you"
# print(greeting, question)
#
# Format manipulation
# 0/1
#
# Nathaniel
# 0/4 did not do any required problem but did class activity
# variable1 = 7
# variable2 = 9
# variable3 = 2
# variable4 = 8
# result_string = f"variable1 = {variable1} variable2 = {variable2} variable3 = {variable3} variable4 = {variable4}"
# print(result_string)
